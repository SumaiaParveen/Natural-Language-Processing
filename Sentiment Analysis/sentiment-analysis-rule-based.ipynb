# %% [markdown]
# ## Unsupervised Sentiment Analysis: Rule Based Approach
#
# * TextBlob
# * Vader
# * SentiWordNet
#
# Author: Sumaia Parveen Shupti
#
# Created on: 8/5/2021
#
# Updated on: 8/5/2021

# %%
#!pip install vaderSentiment

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
df1 = pd.read_csv('../input/womens-ecommerce-clothing-reviews/Womens Clothing E-Commerce Reviews.csv')

# function to analyze the reviews
def analysis(score):
    if score == 1 or score == 2:
        return "Negative"
    elif score == 4 or score == 5:
        return "Positive"
    else:
        return 'Neutral'
    
df1['Sentiment_Original'] = df1['Rating'].apply(analysis)
df1.head()
# Out:
#    Unnamed: 0  Clothing ID  Age                    Title  \
# 0           0          767   33                      NaN
# 1           1         1080   34                      NaN
# 2           2         1077   60  Some major design flaws
# 3           3         1049   50         My favorite buy!
# 4           4          847   47         Flattering shirt
#
#                                          Review Text  Rating  Recommended IND  \
# 0  Absolutely wonderful - silky and sexy and comf...       4                1
# 1  Love this dress!  it's sooo pretty.  i happene...       5                1
# 2  I had such high hopes for this dress and reall...       3                0
# 3  I love, love, love this jumpsuit. it's fun, fl...       5                1
# 4  This shirt is very flattering to all due to th...       5                1
#
#    Positive Feedback Count   Division Name Department Name Class Name  \
# 0                        0       Initmates        Intimate  Intimates
# 1                        4         General         Dresses    Dresses
# 2                        0         General         Dresses    Dresses
# 3                        0  General Petite         Bottoms      Pants
# 4                        6         General            Tops    Blouses
#
#   Sentiment_Original
# 0           Positive
# 1           Positive
# 2            Neutral
# 3           Positive
# 4           Positive

# %%
_counts = df1['Sentiment_Original'].value_counts().to_frame().reset_index()
_counts.columns = ["Sentiment", "Count"]
_counts

import plotly.express as px
fig = px.pie(_counts, values='Count', names='Sentiment', color_discrete_sequence=px.colors.sequential.RdBu, opacity = 0.9, title="Actual Labels")
fig.show()
# Out:
# <div>                            <div id="75edfbe3-23b4-4a3a-a43a-ae5b245a4a99" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("75edfbe3-23b4-4a3a-a43a-ae5b245a4a99")) {                    Plotly.newPlot(                        "75edfbe3-23b4-4a3a-a43a-ae5b245a4a99",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Sentiment=%{label}<br>Count=%{value}<extra></extra>","labels":["Positive","Neutral","Negative"],"legendgroup":"","name":"","opacity":0.9,"showlegend":true,"type":"pie","values":[18208,2871,2407]}],                        {"legend":{"tracegroupgap":0},"piecolorway":["rgb(103,0,31)","rgb(178,24,43)","rgb(214,96,77)","rgb(244,165,130)","rgb(253,219,199)","rgb(247,247,247)","rgb(209,229,240)","rgb(146,197,222)","rgb(67,147,195)","rgb(33,102,172)","rgb(5,48,97)"],"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":tru ...

# %%
col_name = 'Review Text'
df = df1[[col_name]]
df[col_name] = df[col_name].replace('', np.nan)
df = df.dropna()
df.head()
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                                          Review Text
# 0  Absolutely wonderful - silky and sexy and comf...
# 1  Love this dress!  it's sooo pretty.  i happene...
# 2  I had such high hopes for this dress and reall...
# 3  I love, love, love this jumpsuit. it's fun, fl...
# 4  This shirt is very flattering to all due to th...

# %%
## Step 1: Cleaning the text

import re

# Define a function to clean the text
def clean(text):
    # Removes all special characters and numericals leaving the alphabets
    text = re.sub('[^A-Za-z]+', ' ', text) 
    return text

# Cleaning the text in the review column
df['Cleaned Reviews'] = df[col_name].apply(clean)

## Steps 2-4: Tokenization, POS tagging, stopwords removal

import nltk
nltk.download('punkt')
from nltk.tokenize import word_tokenize
from nltk import pos_tag
nltk.download('stopwords')
from nltk.corpus import stopwords
nltk.download('wordnet')
from nltk.corpus import wordnet
# POS tagger dictionary
pos_dict = {'J':wordnet.ADJ, 'V':wordnet.VERB, 'N':wordnet.NOUN, 'R':wordnet.ADV}

def token_stop_pos(text):
    tags = pos_tag(word_tokenize(text))
    newlist = []
    for word, tag in tags:
        if word.lower() not in set(stopwords.words('english')):
            newlist.append(tuple([word, pos_dict.get(tag[0])]))
    return newlist

df['POS tagged'] = df['Cleaned Reviews'].apply(token_stop_pos)

## Step 5: Obtaining the stem words
    
from nltk.stem import WordNetLemmatizer
wordnet_lemmatizer = WordNetLemmatizer()

def lemmatize(pos_data):
    lemma_rew = " "
    for word, pos in pos_data:
        if not pos: 
            lemma = word
            lemma_rew = lemma_rew + " " + lemma
        else:  
            lemma = wordnet_lemmatizer.lemmatize(word, pos=pos)
            lemma_rew = lemma_rew + " " + lemma
    return lemma_rew
    
df['Lemma'] = df['POS tagged'].apply(lemmatize)
# Out:
# [nltk_data] Downloading package punkt to /usr/share/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /usr/share/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /usr/share/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
## TextBlob in rescue

from textblob import TextBlob

# function to calculate subjectivity 
def getSubjectivity(review):
    return TextBlob(review).sentiment.subjectivity

# function to calculate polarity
def getPolarity(review):
    return TextBlob(review).sentiment.polarity

# function to analyze the reviews
def analysis(score):
    if score < 0:
        return 'Negative'
    elif score == 0:
        return 'Neutral'
    else:
        return 'Positive'
    
df = pd.DataFrame(df[[col_name, 'Lemma', 'POS tagged']])
df['Polarity_TextBlob'] = df['Lemma'].apply(getPolarity) 
df['Sentiment_TextBlob'] = df['Polarity_TextBlob'].apply(analysis)
df.head()
# Out:
#                                          Review Text  \
# 0  Absolutely wonderful - silky and sexy and comf...
# 1  Love this dress!  it's sooo pretty.  i happene...
# 2  I had such high hopes for this dress and reall...
# 3  I love, love, love this jumpsuit. it's fun, fl...
# 4  This shirt is very flattering to all due to th...
#
#                                                Lemma  \
# 0        Absolutely wonderful silky sexy comfortable
# 1    Love dress sooo pretty happen find store gla...
# 2    high hope dress really want work initially o...
# 3    love love love jumpsuit fun flirty fabulous ...
# 4    shirt flattering due adjustable front tie pe...
#
#                                           POS tagged  Polarity_TextBlob  \
# 0  [(Absolutely, r), (wonderful, a), (silky, n), ...           0.633333
# 1  [(Love, v), (dress, n), (sooo, a), (pretty, r)...           0.318750
# 2  [(high, a), (hopes, n), (dress, n), (really, r...           0.082300
# 3  [(love, v), (love, r), (love, v), (jumpsuit, n...           0.500000
# 4  [(shirt, n), (flattering, a), (due, a), (adjus...           0.458333
#
#   Sentiment_TextBlob
# 0           Positive
# 1           Positive
# 2           Positive
# 3           Positive
# 4           Positive

# %%
tb_counts = df.Sentiment_TextBlob.value_counts().to_frame().reset_index()
tb_counts.columns = ["Sentiment", "Count"]
tb_counts

import plotly.express as px
fig = px.pie(tb_counts, values='Count', names='Sentiment', color_discrete_sequence=px.colors.sequential.RdBu, opacity = 0.9, title="TextBlob Results")
fig.show()
# Out:
# <div>                            <div id="77762a26-f37a-4cc4-8c84-451199147099" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("77762a26-f37a-4cc4-8c84-451199147099")) {                    Plotly.newPlot(                        "77762a26-f37a-4cc4-8c84-451199147099",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Sentiment=%{label}<br>Count=%{value}<extra></extra>","labels":["Positive","Negative","Neutral"],"legendgroup":"","name":"","opacity":0.9,"showlegend":true,"type":"pie","values":[21206,1294,141]}],                        {"legend":{"tracegroupgap":0},"piecolorway":["rgb(103,0,31)","rgb(178,24,43)","rgb(214,96,77)","rgb(244,165,130)","rgb(253,219,199)","rgb(247,247,247)","rgb(209,229,240)","rgb(146,197,222)","rgb(67,147,195)","rgb(33,102,172)","rgb(5,48,97)"],"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true ...

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# function to calculate vader sentiment  
def vadersentimentanalysis(review):
    vs = analyzer.polarity_scores(review)
    return vs['compound']

df['Polarity_Vader'] = df['Lemma'].apply(vadersentimentanalysis)
df.head()
# Out:
#                                          Review Text  \
# 0  Absolutely wonderful - silky and sexy and comf...
# 1  Love this dress!  it's sooo pretty.  i happene...
# 2  I had such high hopes for this dress and reall...
# 3  I love, love, love this jumpsuit. it's fun, fl...
# 4  This shirt is very flattering to all due to th...
#
#                                                Lemma  \
# 0        Absolutely wonderful silky sexy comfortable
# 1    Love dress sooo pretty happen find store gla...
# 2    high hope dress really want work initially o...
# 3    love love love jumpsuit fun flirty fabulous ...
# 4    shirt flattering due adjustable front tie pe...
#
#                                           POS tagged  Polarity_TextBlob  \
# 0  [(Absolutely, r), (wonderful, a), (silky, n), ...           0.633333
# 1  [(Love, v), (dress, n), (sooo, a), (pretty, r)...           0.318750
# 2  [(high, a), (hopes, n), (dress, n), (really, r...           0.082300
# 3  [(love, v), (love, r), (love, v), (jumpsuit, n...           0.500000
# 4  [(shirt, n), (flattering, a), (due, a), (adjus...           0.458333
#
#   Sentiment_TextBlob  Polarity_Vader
# 0           Positive          0.8991
# 1           Positive          0.9710
# 2           Positive          0.9184
# 3           Positive          0.9437
# 4           Positive          0.9062

# %%
# function to analyse 
def vader_analysis(compound):
    if compound >= 0.5:
        return 'Positive'
    elif compound <= -0.5 :
        return 'Negative'
    else:
        return 'Neutral'
    
df['Sentiment_Vader'] = df['Polarity_Vader'].apply(vader_analysis)
df.head()
# Out:
#                                          Review Text  \
# 0  Absolutely wonderful - silky and sexy and comf...
# 1  Love this dress!  it's sooo pretty.  i happene...
# 2  I had such high hopes for this dress and reall...
# 3  I love, love, love this jumpsuit. it's fun, fl...
# 4  This shirt is very flattering to all due to th...
#
#                                                Lemma  \
# 0        Absolutely wonderful silky sexy comfortable
# 1    Love dress sooo pretty happen find store gla...
# 2    high hope dress really want work initially o...
# 3    love love love jumpsuit fun flirty fabulous ...
# 4    shirt flattering due adjustable front tie pe...
#
#                                           POS tagged  Polarity_TextBlob  \
# 0  [(Absolutely, r), (wonderful, a), (silky, n), ...           0.633333
# 1  [(Love, v), (dress, n), (sooo, a), (pretty, r)...           0.318750
# 2  [(high, a), (hopes, n), (dress, n), (really, r...           0.082300
# 3  [(love, v), (love, r), (love, v), (jumpsuit, n...           0.500000
# 4  [(shirt, n), (flattering, a), (due, a), (adjus...           0.458333
#
#   Sentiment_TextBlob  Polarity_Vader Sentiment_Vader
# 0           Positive          0.8991        Positive
# 1           Positive          0.9710        Positive
# 2           Positive          0.9184        Positive
# 3           Positive          0.9437        Positive
# 4           Positive          0.9062        Positive

# %%
vd_counts = df['Sentiment_Vader'].value_counts().to_frame().reset_index()
vd_counts.columns = ["Sentiment", "Count"]
vd_counts

import plotly.express as px
fig = px.pie(vd_counts, values='Count', names='Sentiment', color_discrete_sequence=px.colors.sequential.RdBu, opacity = 0.9, title="Vader Results")
fig.show()
# Out:
# <div>                            <div id="ee7ea20d-133a-4955-b0f4-1de4a599a0e9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ee7ea20d-133a-4955-b0f4-1de4a599a0e9")) {                    Plotly.newPlot(                        "ee7ea20d-133a-4955-b0f4-1de4a599a0e9",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Sentiment=%{label}<br>Count=%{value}<extra></extra>","labels":["Positive","Neutral","Negative"],"legendgroup":"","name":"","opacity":0.9,"showlegend":true,"type":"pie","values":[20516,1980,145]}],                        {"legend":{"tracegroupgap":0},"piecolorway":["rgb(103,0,31)","rgb(178,24,43)","rgb(214,96,77)","rgb(244,165,130)","rgb(253,219,199)","rgb(247,247,247)","rgb(209,229,240)","rgb(146,197,222)","rgb(67,147,195)","rgb(33,102,172)","rgb(5,48,97)"],"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true ...

# %%
nltk.download('sentiwordnet')
from nltk.corpus import sentiwordnet as swn

def sentiwordnetanalysis(pos_data):
    sentiment = 0
    tokens_count = 0
    for word, pos in pos_data:
        if not pos:
            continue
        lemma = wordnet_lemmatizer.lemmatize(word, pos=pos)
        if not lemma:
            continue
        
        synsets = wordnet.synsets(lemma, pos=pos)
        if not synsets:
            continue

        # Take the first sense, the most common
        synset = synsets[0]
        swn_synset = swn.senti_synset(synset.name())
        sentiment += swn_synset.pos_score() - swn_synset.neg_score()
        tokens_count += 1
        # print(swn_synset.pos_score(),swn_synset.neg_score(),swn_synset.obj_score())
    if not tokens_count:
        return 0
    if sentiment>0:
        return "Positive"
    if sentiment==0:
        return "Neutral"
    else:
        return "Negative"

df['Sentiment_SWNet'] = df['POS tagged'].apply(sentiwordnetanalysis)
df.head()
# Out:
# [nltk_data] Downloading package sentiwordnet to
# [nltk_data]     /usr/share/nltk_data...
# [nltk_data]   Package sentiwordnet is already up-to-date!
#                                          Review Text  \
# 0  Absolutely wonderful - silky and sexy and comf...
# 1  Love this dress!  it's sooo pretty.  i happene...
# 2  I had such high hopes for this dress and reall...
# 3  I love, love, love this jumpsuit. it's fun, fl...
# 4  This shirt is very flattering to all due to th...
#
#                                                Lemma  \
# 0        Absolutely wonderful silky sexy comfortable
# 1    Love dress sooo pretty happen find store gla...
# 2    high hope dress really want work initially o...
# 3    love love love jumpsuit fun flirty fabulous ...
# 4    shirt flattering due adjustable front tie pe...
#
#                                           POS tagged  Polarity_TextBlob  \
# 0  [(Absolutely, r), (wonderful, a), (silky, n), ...           0.633333
# 1  [(Love, v), (dress, n), (sooo, a), (pretty, r)...           0.318750
# 2  [(high, a), (hopes, n), (dress, n), (really, r...           0.082300
# 3  [(love, v), (love, r), (love, v), (jumpsuit, n...           0.500000
# 4  [(shirt, n), (flattering, a), (due, a), (adjus...           0.458333
#
#   Sentiment_TextBlob  Polarity_Vader Sentiment_Vader Sentiment_SWNet
# 0           Positive          0.8991        Positive        Positive
# 1           Positive          0.9710        Positive        Positive
# 2           Positive          0.9184        Positive        Negative
# 3           Positive          0.9437        Positive        Positive
# 4           Positive          0.9062        Positive        Positive

# %%
swn_counts = df['Sentiment_SWNet'].value_counts().to_frame().reset_index()
swn_counts.columns = ["Sentiment", "Count"]
swn_counts

import plotly.express as px
fig = px.pie(swn_counts, values='Count', names='Sentiment', color_discrete_sequence=px.colors.sequential.RdBu, opacity = 0.9, title="SentiWordNet Results")
fig.show()
# Out:
# <div>                            <div id="96a902ea-8f53-44dd-b355-f1c464ad7ab5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("96a902ea-8f53-44dd-b355-f1c464ad7ab5")) {                    Plotly.newPlot(                        "96a902ea-8f53-44dd-b355-f1c464ad7ab5",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Sentiment=%{label}<br>Count=%{value}<extra></extra>","labels":["Positive","Negative","Neutral",0],"legendgroup":"","name":"","opacity":0.9,"showlegend":true,"type":"pie","values":[15841,5927,872,1]}],                        {"legend":{"tracegroupgap":0},"piecolorway":["rgb(103,0,31)","rgb(178,24,43)","rgb(214,96,77)","rgb(244,165,130)","rgb(253,219,199)","rgb(247,247,247)","rgb(209,229,240)","rgb(146,197,222)","rgb(67,147,195)","rgb(33,102,172)","rgb(5,48,97)"],"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin": ...

# %%
df['Original'] = df1[['Sentiment_Original']]
df.head()
# Out:
#                                          Review Text  \
# 0  Absolutely wonderful - silky and sexy and comf...
# 1  Love this dress!  it's sooo pretty.  i happene...
# 2  I had such high hopes for this dress and reall...
# 3  I love, love, love this jumpsuit. it's fun, fl...
# 4  This shirt is very flattering to all due to th...
#
#                                                Lemma  \
# 0        Absolutely wonderful silky sexy comfortable
# 1    Love dress sooo pretty happen find store gla...
# 2    high hope dress really want work initially o...
# 3    love love love jumpsuit fun flirty fabulous ...
# 4    shirt flattering due adjustable front tie pe...
#
#                                           POS tagged  Polarity_TextBlob  \
# 0  [(Absolutely, r), (wonderful, a), (silky, n), ...           0.633333
# 1  [(Love, v), (dress, n), (sooo, a), (pretty, r)...           0.318750
# 2  [(high, a), (hopes, n), (dress, n), (really, r...           0.082300
# 3  [(love, v), (love, r), (love, v), (jumpsuit, n...           0.500000
# 4  [(shirt, n), (flattering, a), (due, a), (adjus...           0.458333
#
#   Sentiment_TextBlob  Polarity_Vader Sentiment_Vader Sentiment_SWNet  Original
# 0           Positive          0.8991        Positive        Positive  Positive
# 1           Positive          0.9710        Positive        Positive  Positive
# 2           Positive          0.9184        Positive        Negative   Neutral
# 3           Positive          0.9437        Positive        Positive  Positive
# 4           Positive          0.9062        Positive        Positive  Positive

# %%
original = df.Original.value_counts().to_frame().reset_index()
original.columns = ['Sentiment', 'Actual Count']
original
# Out:
#   Sentiment  Actual Count
# 0  Positive         17448
# 1   Neutral          2823
# 2  Negative          2370

# %%
textblob = df.Sentiment_TextBlob.value_counts().to_frame().reset_index()
textblob.columns = ['Sentiment', 'TextBlob Count']
textblob
# Out:
#   Sentiment  TextBlob Count
# 0  Positive           21206
# 1  Negative            1294
# 2   Neutral             141

# %%
vader = df.Sentiment_Vader.value_counts().to_frame().reset_index()
vader.columns = ['Sentiment', 'Vader Count']
vader
# Out:
#   Sentiment  Vader Count
# 0  Positive        20516
# 1   Neutral         1980
# 2  Negative          145

# %%
swn = df.Sentiment_SWNet.value_counts().to_frame().reset_index()
swn.columns = ['Sentiment', 'SWNet Count']
swn
# Out:
#   Sentiment  SWNet Count
# 0  Positive        15841
# 1  Negative         5927
# 2   Neutral          872
# 3         0            1

# %%
comp = original.merge(textblob)
comp = comp.merge(vader)
comp = comp.merge(swn)
comp
# Out:
#   Sentiment  Actual Count  TextBlob Count  Vader Count  SWNet Count
# 0  Positive         17448           21206        20516        15841
# 1   Neutral          2823             141         1980          872
# 2  Negative          2370            1294          145         5927

# %%
import plotly.express as px

fig = px.bar(comp, x="Sentiment", y=["Actual Count", "TextBlob Count", "Vader Count", "SWNet Count"], title="Comparison of Results: Actual- TextBlob- Vader- SentiWordNet", color_discrete_sequence=px.colors.sequential.RdBu)
fig.show()
# Out:
# <div>                            <div id="2bbf69c2-1197-4af3-80ff-57eecf0f074a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2bbf69c2-1197-4af3-80ff-57eecf0f074a")) {                    Plotly.newPlot(                        "2bbf69c2-1197-4af3-80ff-57eecf0f074a",                        [{"alignmentgroup":"True","hovertemplate":"variable=Actual Count<br>Sentiment=%{x}<br>value=%{y}<extra></extra>","legendgroup":"Actual Count","marker":{"color":"rgb(103,0,31)","pattern":{"shape":""}},"name":"Actual Count","offsetgroup":"Actual Count","orientation":"v","showlegend":true,"textposition":"auto","type":"bar","x":["Positive","Neutral","Negative"],"xaxis":"x","y":[17448,2823,2370],"yaxis":"y"},{"alignmentgroup":"True","hovertemplate":"variable=TextBlob Count<br>Sentiment=%{x}<br>value=%{y}<extra></extra>","legendgroup":"TextBlob Count","marker":{"color":"rgb(178,24,43)","pattern":{"shape":""}},"name":"TextBlob Count","offsetgroup":"TextBlob Count","orientation":"v","showlegend":true,"textposition":"auto","type":"bar","x":["Positive","Neutral","Negative"],"xaxis":"x","y":[21206,141,1294],"yaxis":"y"},{"alignmentgroup":"True","hovertemplate":"variable=Vader Count<br>Sentiment=%{x}<br>value=%{y}<extra></extra>","legendgroup":"Vader Count","marker":{"color":"rgb(214,96,77)","pattern":{"shape":""}},"name":"Vader Count","offsetgroup":"Vader Count","orientation":"v","showlegend":true,"textposition":"auto","type":"bar","x":["Positive","Neutral","Negative"],"xaxis":"x","y":[20516,1980,145],"yaxis":"y"},{"alignmentgroup":"True","hovertemplate":"variable=SWNet Count<br>Sentiment=%{x}<br>value=%{y}<extra></extra>","legendgroup":"SWNet Count","marker":{"color":"rgb(244,165,130)","pattern":{"shape":""}},"name":"SWNet Count","offsetgroup":"SWNet Count","orientation":"v","showlegend":true,"textposition":"auto","type":"bar","x":["Positive","Neutral","Negative"],"xaxis":"x","y":[15841,872,5927],"yaxis":"y"}],                        {"barmode":"relative","legend":{"title":{"text":"variable"},"tracegroupgap":0},"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"] ...

# %% [markdown]
# ## References
#
# * https://www.alphabold.com/sentiment-analysis-the-lexicon-based-approach/
# * https://www.analyticsvidhya.com/blog/2021/06/rule-based-sentiment-analysis-in-python/
